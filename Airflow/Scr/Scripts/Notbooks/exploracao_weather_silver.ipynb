# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
dataset = pd.read_csv('/home/gabrielgalani/Documents/Airflow/Datalake/Bronze/Weather/extract_date=2023-09-07/weather_20230907.csv')
dataset.head()
# Out:
#                         name    datetime  tempmax  tempmin  temp  \
# 0  Boston, MA, United States  2023-09-06     28.8     20.7  25.6
# 1  Boston, MA, United States  2023-09-07     31.8     25.5  28.0
# 2  Boston, MA, United States  2023-09-08     28.9     23.4  25.8
# 3  Boston, MA, United States  2023-09-09     26.2     23.6  24.7
# 4  Boston, MA, United States  2023-09-10     25.8     22.1  23.8
#
#    feelslikemax  feelslikemin  feelslike   dew  humidity  precip  precipprob  \
# 0          31.3          20.7       26.1  20.5      74.0     0.0         0.0
# 1          35.3          25.5       29.7  21.4      68.1     0.0         5.0
# 2          31.6          23.4       26.6  21.1      75.6     0.6         8.0
# 3          26.2          23.6       24.7  21.7      83.7     3.7        31.0
# 4          25.8          22.1       23.8  21.4      86.5     5.2        47.0
#
#    precipcover preciptype  snow  snowdepth  windgust  windspeed  winddir  \
# ...

# %%
column_list_temp = [
    'name',
    'datetime',
    'tempmin',
    'temp',
    'feelslikemax',
    'feelslikemin',
    'feelslike',
    'dew'

]

column_list_temp_condicoes = [
    'name',
    'datetime',
    'humidity',
    'precip',
    'snow',
    'windspeed',
    'cloudcover',
    'uvindex',
    'sunrise',
    'sunset',
    'conditions',
    'description',
    'icon'
]

dataset_temp = dataset[column_list_temp]
datasaet_condicoes = dataset[column_list_temp_condicoes]

# %%
dataset_temp.head()
# Out:
#                         name    datetime  tempmin  temp  feelslikemax  \
# 0  Boston, MA, United States  2023-09-06     20.7  25.6          31.3
# 1  Boston, MA, United States  2023-09-07     25.5  28.0          35.3
# 2  Boston, MA, United States  2023-09-08     23.4  25.8          31.6
# 3  Boston, MA, United States  2023-09-09     23.6  24.7          26.2
# 4  Boston, MA, United States  2023-09-10     22.1  23.8          25.8
#
#    feelslikemin  feelslike   dew
# 0          20.7       26.1  20.5
# 1          25.5       29.7  21.4
# 2          23.4       26.6  21.1
# 3          23.6       24.7  21.7
# 4          22.1       23.8  21.4

# %%
datasaet_condicoes.head()
# Out:
#                         name    datetime  humidity  precip  snow  windspeed  \
# 0  Boston, MA, United States  2023-09-06      74.0     0.0     0       20.2
# 1  Boston, MA, United States  2023-09-07      68.1     0.0     0       20.3
# 2  Boston, MA, United States  2023-09-08      75.6     0.6     0       20.5
# 3  Boston, MA, United States  2023-09-09      83.7     3.7     0       16.6
# 4  Boston, MA, United States  2023-09-10      86.5     5.2     0       15.8
#
#    cloudcover  uvindex              sunrise               sunset  \
# 0        22.7        6  2023-09-06T06:14:25  2023-09-06T19:10:11
# 1        14.3        7  2023-09-07T06:15:28  2023-09-07T19:08:27
# 2        50.1        6  2023-09-08T06:16:31  2023-09-08T19:06:43
# 3        68.1        5  2023-09-09T06:17:34  2023-09-09T19:04:58
# 4        81.7        4  2023-09-10T06:18:37  2023-09-10T19:03:13
#
#                conditions                                        description  \
# ...

# %%
date_extract = datetime.now().date()
date_extract.strftime('%Y%m%d')
file = f'extract_date={date_extract}.csv'
file_path = '/home/gabrielgalani/Documents/Airflow/datalake/silver/weather/temperatura/'

dataset_temp.to_csv(file_path + file)

# %%
date_extract = datetime.now().date()
date_extract.strftime('%Y%m%d')
file = f'extract_date={date_extract}.csv'
file_path = '/home/gabrielgalani/Documents/Airflow/datalake/silver/weather/condicoes/'

datasaet_condicoes.to_csv(file_path + file)
